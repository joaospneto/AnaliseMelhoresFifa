# %% [markdown]
# <a href="https://colab.research.google.com/github/joaospneto/AnaliseMelhoresFifa/blob/main/Analisando_dados_fifa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
dados = pd.read_csv("/content/fifa.csv")

# %% [markdown]
# ANALISANDO DADOS DO FIFA 2019

# %%
dados
# Out:
#        Unnamed: 0      ID                Name  Age  \
# 0               0  158023            L. Messi   31
# 1               1   20801   Cristiano Ronaldo   33
# 2               2  190871           Neymar Jr   26
# 3               3  193080              De Gea   27
# 4               4  192985        K. De Bruyne   27
# ...           ...     ...                 ...  ...
# 18202       18202  238813        J. Lundstram   19
# 18203       18203  243165  N. Christoffersson   19
# 18204       18204  241638           B. Worman   16
# 18205       18205  246268      D. Walker-Rice   17
# 18206       18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3      https://cdn.sofifa.org/players/4/19/193080.png       Spain
# ...

# %%
dados.head(10)
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
# 5           5  183277          E. Hazard   27
# 6           6  177003          L. Modrić   32
# 7           7  176580          L. Suárez   31
# 8           8  155862       Sergio Ramos   32
# 9           9  200389           J. Oblak   25
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
# 5  https://cdn.sofifa.org/players/4/19/183277.png     Belgium
# ...

# %%
dados.tail(3)
# Out:
#        Unnamed: 0      ID            Name  Age  \
# 18204       18204  241638       B. Worman   16
# 18205       18205  246268  D. Walker-Rice   17
# 18206       18206  246269       G. Nugent   16
#
#                                                 Photo Nationality  \
# 18204  https://cdn.sofifa.org/players/4/19/241638.png     England
# 18205  https://cdn.sofifa.org/players/4/19/246268.png     England
# 18206  https://cdn.sofifa.org/players/4/19/246269.png     England
#
#                                       Flag  Overall  Potential  \
# 18204  https://cdn.sofifa.org/flags/14.png       47         67
# 18205  https://cdn.sofifa.org/flags/14.png       47         66
# 18206  https://cdn.sofifa.org/flags/14.png       46         66
#
#                    Club  ... Composure Marking StandingTackle  SlidingTackle  \
# 18204  Cambridge United  ...      41.0    32.0           13.0           11.0
# 18205   Tranmere Rovers  ...      46.0    20.0           25.0           27.0
# ...

# %%
dados.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag',
#        'Overall', 'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
#        'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
# ...

# %%
dados.index
# Out:
# RangeIndex(start=0, stop=18207, step=1)

# %%
dados[["Name",'Wage',"Nationality",]]
# Out:
#                      Name   Wage Nationality
# 0                L. Messi  €565K   Argentina
# 1       Cristiano Ronaldo  €405K    Portugal
# 2               Neymar Jr  €290K      Brazil
# 3                  De Gea  €260K       Spain
# 4            K. De Bruyne  €355K     Belgium
# ...                   ...    ...         ...
# 18202        J. Lundstram    €1K     England
# 18203  N. Christoffersson    €1K      Sweden
# 18204           B. Worman    €1K     England
# 18205      D. Walker-Rice    €1K     England
# 18206           G. Nugent    €1K     England
#
# [18207 rows x 3 columns]

# %%
dados.iloc[1:4]
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
#
#                                             Photo Nationality  \
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
#
#                                   Flag  Overall  Potential  \
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
#
#                   Club  ... Composure Marking StandingTackle  SlidingTackle  \
# 1             Juventus  ...      95.0    28.0           31.0           23.0
# 2  Paris Saint-Germain  ...      94.0    27.0           24.0           33.0
# ...

# %%
dados.iloc[2,2]
# Out:
# 'Neymar Jr'

# %%
dados.loc[dados['Nationality'] == 'Brazil']

#localziar por nacionalidade
# Out:
#        Unnamed: 0      ID              Name  Age  \
# 2               2  190871         Neymar Jr   26
# 27             27  200145          Casemiro   26
# 32             32  189242          Coutinho   26
# 35             35  176676           Marcelo   30
# 39             39  164240      Thiago Silva   33
# ...           ...     ...               ...  ...
# 17059       17059  243750  Gianluca Zanette   21
# 17446       17446  235949         Strefezza   21
# 17588       17588  244311     Lucas Ribeiro   19
# 17611       17611  241268   Felipe Ferreyra   20
# 18170       18170  246447   Nicolas Firmino   17
#
#                                                 Photo Nationality  \
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 27     https://cdn.sofifa.org/players/4/19/200145.png      Brazil
# 32     https://cdn.sofifa.org/players/4/19/189242.png      Brazil
# 35     https://cdn.sofifa.org/players/4/19/176676.png      Brazil
# ...

# %%
dados.loc[dados['Age'] == 36]

#filtro por idade = 36 anos
# Out:
#        Unnamed: 0      ID            Name  Age  \
# 109           109   41236  Z. Ibrahimović   36
# 315           315  113422     David Villa   36
# 317           317   48940         P. Čech   36
# 411           411   45186         Joaquín   36
# 544           544  146748     Diego López   36
# ...           ...     ...             ...  ...
# 16171       16171  194248   Ryang Yong Gi   36
# 16310       16310   11800        C. Weale   36
# 16449       16449   22391      R. Cretaro   36
# 16565       16565  232893     K. Kitamoto   36
# 17704       17704  244440     F. Nicastro   36
#
#                                                 Photo          Nationality  \
# 109     https://cdn.sofifa.org/players/4/19/41236.png               Sweden
# 315    https://cdn.sofifa.org/players/4/19/113422.png                Spain
# 317     https://cdn.sofifa.org/players/4/19/48940.png       Czech Republic
# 411     https://cdn.sofifa.org/players/4/19/45186.png                Spain
# ...

# %%
dados.sort_values("Age", ascending =False)

#lista com os jogadores mais velhos e mais jovens
# Out:
#        Unnamed: 0      ID           Name  Age  \
# 4741         4741  140029       O. Pérez   45
# 18183       18183   53748  K. Pilkington   44
# 17726       17726   51963      T. Warner   44
# 10545       10545  140183    S. Narazaki   42
# 7225         7225  142998       C. Muñoz   41
# ...           ...     ...            ...  ...
# 17921       17921  246601     J. Rowland   16
# 17887       17887  246009       M. Tilio   16
# 15363       15363  245015      Y. Roemer   16
# 17881       17881  242165       R. Hauge   16
# 18206       18206  246269      G. Nugent   16
#
#                                                 Photo        Nationality  \
# 4741   https://cdn.sofifa.org/players/4/19/140029.png             Mexico
# 18183   https://cdn.sofifa.org/players/4/19/53748.png            England
# 17726   https://cdn.sofifa.org/players/4/19/51963.png  Trinidad & Tobago
# 10545  https://cdn.sofifa.org/players/4/19/140183.png              Japan
# ...

# %%
dados.sort_values("Weight")

#os jogadores mais pesados
# Out:
#        Unnamed: 0      ID            Name  Age  \
# 13338       13338  235600   B. Al Mutairi   28
# 17157       17157  242566    K. Yamaguchi   23
# 4390         4390  214919        D. Rojas   23
# 7126         7126  225150       A. Araujo   21
# 15585       15585  227726     I. Al Talhi   23
# ...           ...     ...             ...  ...
# 13279       13279  239679    P. Mazzocchi   22
# 13280       13280  244543       Y. Ammour   19
# 13281       13281  212800  Jwa Joon Hyeop   27
# 13282       13282  231232      O. Marrufo   25
# 13283       13283  232256     Han Pengfei   25
#
#                                                 Photo     Nationality  \
# 13338  https://cdn.sofifa.org/players/4/19/235600.png    Saudi Arabia
# 17157  https://cdn.sofifa.org/players/4/19/242566.png           Japan
# 4390   https://cdn.sofifa.org/players/4/19/214919.png           Chile
# 7126   https://cdn.sofifa.org/players/4/19/225150.png        Portugal
# ...

# %%
dados["total"] = dados['Acceleration'] + dados['Agility'] + dados['Reactions']

#selecionar as colunas com as habilidades dos jogadores

# %%
dados
# Out:
#        Unnamed: 0      ID                Name  Age  \
# 0               0  158023            L. Messi   31
# 1               1   20801   Cristiano Ronaldo   33
# 2               2  190871           Neymar Jr   26
# 3               3  193080              De Gea   27
# 4               4  192985        K. De Bruyne   27
# ...           ...     ...                 ...  ...
# 18202       18202  238813        J. Lundstram   19
# 18203       18203  243165  N. Christoffersson   19
# 18204       18204  241638           B. Worman   16
# 18205       18205  246268      D. Walker-Rice   17
# 18206       18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3      https://cdn.sofifa.org/players/4/19/193080.png       Spain
# ...

# %%
dados = dados[["Name", "total"]]
dados.sort_values("total", ascending=False)

#lista com os melhores jogadores
# Out:
#                  Name  total
# 2           Neymar Jr  284.0
# 5           E. Hazard  279.0
# 0            L. Messi  277.0
# 26           M. Salah  276.0
# 50         D. Mertens  275.0
# ...               ...    ...
# 13279    P. Mazzocchi    NaN
# 13280       Y. Ammour    NaN
# 13281  Jwa Joon Hyeop    NaN
# 13282      O. Marrufo    NaN
# 13283     Han Pengfei    NaN
#
# [18207 rows x 2 columns]

# %%
dados.head(5)
# Out:
#                 Name  total
# 0           L. Messi  277.0
# 1  Cristiano Ronaldo  272.0
# 2          Neymar Jr  284.0
# 3             De Gea  207.0
# 4       K. De Bruyne  248.0

# %%
dados.to_excel("dados.xlsx", index=False)

#lista com os melhores jogadores exportadas para o excel
